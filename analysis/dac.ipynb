# %% [markdown]
# # Direct Air Capture

# %% [markdown]
# * 2050 탄소중립 시나리오 B안에서는 직접 공기 포집(DAC)를 이용해 7.4 MtCO2-eq의 온실가스 감축을 계획함.
# * 2025년 0, 2050년 7.4, 선형경로

# %%
7.4 / 5 / 3.66667
# Out:
# 0.40363599669454847

# %%
7.4 / 5 / 3.66667 * 2
# Out:
# 0.8072719933890969

# %%
for year in range(2030, 2055, 5):
    const_mtco2e = 7.4 / 5 * (year-2025)/5
    const_mtc = const_mtco2e / 3.66667
    print(year, const_mtco2e, const_mtc)
# Out:
# 2030 1.48 0.40363599669454847
# 2035 2.96 0.8072719933890969
# 2040 4.4399999999999995 1.2109079900836452
# 2045 5.92 1.6145439867781939
# 2050 7.4 2.0181799834727423

# %% [markdown]
# ```xml
#
# <?xml version="1.0" encoding="UTF-8"?><scenario>
#    <world>
#       <region name="South Korea">
#          <policy-portfolio-standard name="dac-floor">
#             <policyType>subsidy</policyType>
#             <market>South Korea</market>
#             <min-price year="2030">0</min-price>
#             <min-price year="2035">0</min-price>
#             <min-price year="2040">0</min-price>
#             <constraint year="2030">0.4036</constraint>
#             <constraint year="2035">0.8072</constraint>
#             <constraint year="2040">1.2109</constraint>
#             <constraint year="2045">1.6145</constraint>
#             <constraint year="2050">2.018</constraint>
#    	   </policy-portfolio-standard>
#       </region>
#    </world>
# </scenario>
#
#
#
# ```
