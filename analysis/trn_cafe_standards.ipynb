# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Current Policy

# %% [markdown]
# 한국은 2030년까지 승용차의 연비기준을 2020년 대비 30% 상향

# %% [markdown]
# # Enhanced Policy

# %% [markdown]
# * 연비기준 상향 추세 2035년까지 지속(45% 상향)
# * 화물차에도 적용 (2035년까지 30%)

# %% [markdown]
# ``` xml
#
#                         <period year="2020">
#                             <loadFactor>1.46</loadFactor>
#                             <tracking-non-energy-input name="non-energy">
#                                 <capital-coef>0.00212740112816817</capital-coef>
#                                 <tracking-market>consumer durable</tracking-market>
#                                 <depreciation-rate>0.0666666666666667</depreciation-rate>
#                                 <input-cost>0.2128</input-cost>
#                             </tracking-non-energy-input>
#                             <minicam-energy-input name="refined liquids enduse">
#                                 <coefficient>2449.0917851</coefficient>
#                                 <market-name>South Korea</market-name>
#                             </minicam-energy-input>
#                         </period>
#
# ```

# %% [markdown]
# GCAM 모형에서 2020년 승용차 연비는 2449.0917임.

# %%
coef_2020 = 2449.0917851
coef_2025 = coef_2020 * 0.85
coef_2030 = coef_2020 * 0.70
coef_2035 = coef_2020 * 0.55
coef_2020, coef_2025, coef_2030, coef_2035
# Out:
# (2449.0917851, 2081.728017335, 1714.3642495699999, 1347.0004818050002)

# %% [markdown]
# 화물차의 2020년 연비는 1387.17임

# %% [markdown]
# ``` xml
#
#
#                         <period year="2020">
#                             <loadFactor>0.69</loadFactor>
#                             <tracking-non-energy-input name="non-energy">
#                                 <capital-coef>0.002885893534842</capital-coef>
#                                 <tracking-market>capital</tracking-market>
#                                 <depreciation-rate>0.0333333333333333</depreciation-rate>
#                                 <input-cost>0.8024</input-cost>
#                             </tracking-non-energy-input>
#                             <minicam-energy-input name="refined liquids enduse">
#                                 <coefficient>1387.1664172</coefficient>
#                                 <market-name>South Korea</market-name>
#                             </minicam-energy-input>
#                         </period>
#
# ```

# %%
coef_2020 = 1387.1664172
coef_2025 = coef_2020 * 0.90
coef_2030 = coef_2020 * 0.80
coef_2035 = coef_2020 * 0.70
coef_2020, coef_2025, coef_2030, coef_2035
# Out:
# (1387.1664172, 1248.4497754800002, 1109.73313376, 971.01649204)
