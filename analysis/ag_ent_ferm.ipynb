# %%
import pandas as pd

# %% [markdown]
# # 장내발효

# %% [markdown]
# 한국은 장내 발효에서 2030년 예상 배출량 4.758 MtCO2e 중 0.751을 감소시킬 계획

# %%
coef = 1 - 751 / 4758
coef
# Out:
# 0.8421605716687683

# %% [markdown]
# ## Beef

# %%
0.21049 * coef
# Out:
# 0.17726637873055906

# %%
0.00775192 * coef
# Out:
# 0.006528361378730559

# %% [markdown]
# ## Dairy

# %%
0.0170954 * coef
# Out:
# 0.014397071836906262

# %%
0.00062959 * coef
# Out:
# 0.0005302158743169398

# %% [markdown]
# ## SheepGoat

# %%
0.432882 * coef
# Out:
# 0.36455615258511975

# %%
0.0159423 * coef
# Out:
# 0.013425976481715006
