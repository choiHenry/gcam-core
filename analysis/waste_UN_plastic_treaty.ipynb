# %%
import pandas as pd
import numpy as np

# %% [markdown]
# * UN Plastic Treaty agrees to reduce 25% of waste plastic by 2040
# * Data Source:「전국폐기물발생및처리현황」환경부, https://stat.me.go.kr/portal/intro/siteMapPage.do
# * Data Valication: `20631b9b-2023-플라스틱-대한민국2.0-보고서_최종_저용량.pdf`
# * Estimation Method of Effects on GHG Emission: WARM v16 by EPA: `warm-korea-plastic.xlsx`

# %% [markdown]
# Agreement and adoption of the Treaty reduces 0.777 MtCO2-eq by 2030, 1.554 MtCO2-eq by 2035 and 2.331 MtCO2-eq by 2040.
